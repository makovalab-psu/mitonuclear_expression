# %%
import pandas as pd
#pd.set_option("display.max_rows", None, "display.max_columns", None)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy import stats
import statistics
import statsmodels.api as sm
from itertools import permutations
#import pdfkit as pdf

import seaborn as sns; sns.set(style="ticks", color_codes=True)
#iris = sns.load_dataset("iris")
#g = sns.pairplot(iris)

from Bio import SeqIO
import sys

#%load_ext rpy2.ipython

# %%
# The list of mtDNA protein-coding genes.
list_mtdna = [ 'MT-ND1','MT-ND2','MT-CO1','MT-CO2','MT-ATP8','MT-ATP6','MT-CO3','MT-ND3','MT-ND4L','MT-ND4','MT-CYB','MT-ND5','MT-ND6'
             ,'MT-ATP8_MT-ATP6','MT-ND4L_MT-ND4' ]

# The list of SRR samples used.
list_SRR = ['SRR1074719','SRR1077288','SRR1077805','SRR1080766','SRR1327327','SRR1365448']

# %%
# Connecting SRR ID to more info.
dict_info = {   'SRR1074719':['GTEX-XPVG','EuAm','Male','Muscle - Skeletal'],
                'SRR1077288':['GTEX-SSA3','AfAm','Male','Muscle - Skeletal'],
                'SRR1077805':['GTEX-XYKS','AfAm','Female','Muscle - Skeletal'],
                'SRR1080766':['GTEX-XUZC','EuAm','Female','Muscle - Skeletal'],
                'SRR1365448':['GTEX-11WQC','AfAm','Male','Muscle - Skeletal'],
                'SRR1327327':['GTEX-11WQC','AfAm','Male','Testis']
            }
dict_info
# Out:
# {'SRR1074719': ['GTEX-XPVG', 'EuAm', 'Male', 'Muscle - Skeletal'],
#  'SRR1077288': ['GTEX-SSA3', 'AfAm', 'Male', 'Muscle - Skeletal'],
#  'SRR1077805': ['GTEX-XYKS', 'AfAm', 'Female', 'Muscle - Skeletal'],
#  'SRR1080766': ['GTEX-XUZC', 'EuAm', 'Female', 'Muscle - Skeletal'],
#  'SRR1365448': ['GTEX-11WQC', 'AfAm', 'Male', 'Muscle - Skeletal'],
#  'SRR1327327': ['GTEX-11WQC', 'AfAm', 'Male', 'Testis']}

# %% [markdown]
# ## RNA-Seq was replicated for small number of samples (Skeletal muscle), using the GTEx docker pipeline.
# ### The "original" mapping replicates these exactly (overlapping sections of genes were excluded), whereas we also remapped using a "bicistronic" transcript that joins overlapping genes into a single transcript.

# %%
def merge_gct_files():
    ###########
    # ORIGINAL: 
    # Get the first two columns (ENS_ID,GENE) from a file.
    df_orig = pd.read_table('../data/transfer.2022-04-18/docker_out/original/SRR1074719.Aligned.sortedByCoord.out.md.bam.gene_tpm.gct'
              , skiprows=2)
    # Exclude the TPM column (added for all samples later).
    df_orig = df_orig.iloc[:,:2]
    
    # Iterate to add TPM from all SRR files provided.
    ##list_SRR=['SRR1074719','SRR1077288','SRR1077805','SRR1080766','SRR1327327','SRR1365448']
    for SRR in list_SRR:
        df_in = pd.read_table('../data/transfer.2022-04-18/docker_out/original/'+SRR+'.Aligned.sortedByCoord.out.md.bam.gene_tpm.gct'
              , skiprows=2)
        # Change columns header from 'TPM' to SRR ID.
        df_in.columns = ['Name','Description',SRR]
        # Merge this sample's TPM column to the main df.
        df_orig = pd.merge(df_orig,df_in)
    
    ##############
    # BICISTRONIC: 
    # Get the first two columns (ENS_ID,GENE) from a file.
    df_bic = pd.read_table('../data/transfer.2022-04-18/docker_out/bicistronic/SRR1074719.Aligned.sortedByCoord.out.md.bam.gene_tpm.gct'
              , skiprows=2)
    # Exclude the TPM column (added for all samples later).
    df_bic = df_bic.iloc[:,:2]
    
    # Iterate to add TPM from all SRR files provided.
    for SRR in ['SRR1074719','SRR1077288','SRR1077805','SRR1080766','SRR1327327','SRR1365448']:
        df_in = pd.read_table('../data/transfer.2022-04-18/docker_out/bicistronic/'+SRR+'.Aligned.sortedByCoord.out.md.bam.gene_tpm.gct'
              , skiprows=2)
        # Change columns header from 'TPM' to SRR ID.
        df_in.columns = ['Name','Description',SRR]
        # Merge this sample's TPM column to the main df.
        df_bic = pd.merge(df_bic,df_in)
    
    # Export the merged TPMs.
    return([df_orig,df_bic])

def keep_mtdna(dfs):
    # Keep genes in the list_mtDNA (mitochondrial protein-coding genes).
    return( [ dfs[0][dfs[0]['Description'].isin(list_mtdna)],
             dfs[1][dfs[1]['Description'].isin(list_mtdna)] ] )

def transpose_df(df):
    # Transpose df.
    df_transp = df.transpose().reset_index()
    # Replace column headers with gene names.
    df_transp.columns = df_transp.iloc[1]
    df_transp = df_transp.iloc[2:]
    df_melt = df_transp.melt(id_vars='Description',
                value_vars=list(df_transp.columns)[1:] ,
                #value_vars=['MT-ND1','MT-ND2','MT-CO1','MT-CO2','MT-CO3','MT-ND3','MT-CYB','MT-ND5','MT-ND6'],
                var_name=['Gene'])
    return(df_melt)

def add_info(df):
    df_info = df
    df_info['Population'] = [ dict_info[SRR][1] for SRR in df_info['Description'] ]
    df_info['Tissue'] = [ dict_info[SRR][3] for SRR in df_info['Description'] ]
    df_info['short_ID'] = [ dict_info[SRR][0] for SRR in df_info['Description'] ]
    df_info['Sex'] = [ dict_info[SRR][2] for SRR in df_info['Description'] ]
    # Exclude Testis sample.
    df_info = df_info[df_info['Tissue']=='Muscle - Skeletal']    
    return(df_info)


df_orig,df_bic = keep_mtdna(merge_gct_files())

df_orig = add_info(transpose_df(df_orig))
df_bic = add_info(transpose_df(df_bic))

df_orig['Mapping'] = 'Original'
df_bic['Mapping'] = 'Bicistronic'

# %%
df_orig
# Out:
#    Description    Gene    value Population             Tissue    short_ID  \
# 0   SRR1074719  MT-ND1  34972.3       EuAm  Muscle - Skeletal   GTEX-XPVG
# 1   SRR1077288  MT-ND1  16752.3       AfAm  Muscle - Skeletal   GTEX-SSA3
# 2   SRR1077805  MT-ND1  19851.8       AfAm  Muscle - Skeletal   GTEX-XYKS
# 3   SRR1080766  MT-ND1  32457.1       EuAm  Muscle - Skeletal   GTEX-XUZC
# 5   SRR1365448  MT-ND1  20237.1       AfAm  Muscle - Skeletal  GTEX-11WQC
# ..         ...     ...      ...        ...                ...         ...
# 72  SRR1074719  MT-CYB  38823.7       EuAm  Muscle - Skeletal   GTEX-XPVG
# 73  SRR1077288  MT-CYB  21297.6       AfAm  Muscle - Skeletal   GTEX-SSA3
# 74  SRR1077805  MT-CYB  30901.4       AfAm  Muscle - Skeletal   GTEX-XYKS
# 75  SRR1080766  MT-CYB  28230.3       EuAm  Muscle - Skeletal   GTEX-XUZC
# 77  SRR1365448  MT-CYB  23157.5       AfAm  Muscle - Skeletal  GTEX-11WQC
#
#        Sex   Mapping
# 0     Male  Original
# 1     Male  Original
# 2   Female  Original
# 3   Female  Original
# 5     Male  Original
# ..     ...       ...
# 72    Male  Original
# 73    Male  Original
# 74  Female  Original
# 75  Female  Original
# 77    Male  Original
#
# [65 rows x 8 columns]

# %%
df_bic
# Out:
#    Description             Gene    value Population             Tissue  \
# 0   SRR1074719           MT-ND1  37608.2       EuAm  Muscle - Skeletal
# 1   SRR1077288           MT-ND1    17245       AfAm  Muscle - Skeletal
# 2   SRR1077805           MT-ND1    20623       AfAm  Muscle - Skeletal
# 3   SRR1080766           MT-ND1  34105.4       EuAm  Muscle - Skeletal
# 5   SRR1365448           MT-ND1  21128.5       AfAm  Muscle - Skeletal
# 6   SRR1074719           MT-ND2  26775.9       EuAm  Muscle - Skeletal
# 7   SRR1077288           MT-ND2  18173.6       AfAm  Muscle - Skeletal
# 8   SRR1077805           MT-ND2  22997.1       AfAm  Muscle - Skeletal
# 9   SRR1080766           MT-ND2  30282.2       EuAm  Muscle - Skeletal
# 11  SRR1365448           MT-ND2  17000.8       AfAm  Muscle - Skeletal
# 12  SRR1074719           MT-CO1  84286.9       EuAm  Muscle - Skeletal
# 13  SRR1077288           MT-CO1  32091.4       AfAm  Muscle - Skeletal
# 14  SRR1077805           MT-CO1  42732.2       AfAm  Muscle - Skeletal
# 15  SRR1080766           MT-CO1  32765.2       EuAm  Muscle - Skeletal
# 17  SRR1365448           MT-CO1  18563.9       AfAm  Muscle - Skeletal
# 18  SRR1074719           MT-CO2  68691.3       EuAm  Muscle - Skeletal
# 19  SRR1077288           MT-CO2  22827.3       AfAm  Muscle - Skeletal
# 20  SRR1077805           MT-CO2  24385.6       AfAm  Muscle - Skeletal
# 21  SRR1080766           MT-CO2  34239.4       EuAm  Muscle - Skeletal
# 23  SRR1365448           MT-CO2  28855.5       AfAm  Muscle - Skeletal
# 24  SRR1074719           MT-CO3  71855.8       EuAm  Muscle - Skeletal
# 25  SRR1077288           MT-CO3  36111.9       AfAm  Muscle - Skeletal
# 26  SRR1077805           MT-CO3  29152.8       AfAm  Muscle - Skeletal
# 27  SRR1080766           MT-CO3  28298.5       EuAm  Muscle - Skeletal
# 29  SRR1365448           MT-CO3  36640.7       AfAm  Muscle - Skeletal
# 30  SRR1074719           MT-ND3  19609.3       EuAm  Muscle - Skeletal
# 31  SRR1077288           MT-ND3  11592.4       AfAm  Muscle - Skeletal
# 32  SRR1077805           MT-ND3  9047.11       AfAm  Muscle - Skeletal
# 33  SRR1080766           MT-ND3  14446.6       EuAm  Muscle - Skeletal
# 35  SRR1365448           MT-ND3  11531.6       AfAm  Muscle - Skeletal
# 36  SRR1074719           MT-ND5  18782.5       EuAm  Muscle - Skeletal
# 37  SRR1077288           MT-ND5  9438.55       AfAm  Muscle - Skeletal
# 38  SRR1077805           MT-ND5  16584.7       AfAm  Muscle - Skeletal
# 39  SRR1080766           MT-ND5  13753.2       EuAm  Muscle - Skeletal
# 41  SRR1365448           MT-ND5  4141.73       AfAm  Muscle - Skeletal
# 42  SRR1074719           MT-ND6    28505       EuAm  Muscle - Skeletal
# 43  SRR1077288           MT-ND6  12386.5       AfAm  Muscle - Skeletal
# 44  SRR1077805           MT-ND6  24486.5       AfAm  Muscle - Skeletal
# 45  SRR1080766           MT-ND6  18761.8       EuAm  Muscle - Skeletal
# 47  SRR1365448           MT-ND6  4221.91       AfAm  Muscle - Skeletal
# 48  SRR1074719           MT-CYB  41749.9       EuAm  Muscle - Skeletal
# 49  SRR1077288           MT-CYB  21924.1       AfAm  Muscle - Skeletal
# 50  SRR1077805           MT-CYB  32101.8       AfAm  Muscle - Skeletal
# 51  SRR1080766           MT-CYB  29664.1       EuAm  Muscle - Skeletal
# 53  SRR1365448           MT-CYB  24177.5       AfAm  Muscle - Skeletal
# 54  SRR1074719  MT-ATP8_MT-ATP6  78093.5       EuAm  Muscle - Skeletal
# 55  SRR1077288  MT-ATP8_MT-ATP6  31216.4       AfAm  Muscle - Skeletal
# 56  SRR1077805  MT-ATP8_MT-ATP6  40442.8       AfAm  Muscle - Skeletal
# 57  SRR1080766  MT-ATP8_MT-ATP6    51532       EuAm  Muscle - Skeletal
# 59  SRR1365448  MT-ATP8_MT-ATP6  42547.7       AfAm  Muscle - Skeletal
# 60  SRR1074719   MT-ND4L_MT-ND4  63458.3       EuAm  Muscle - Skeletal
# 61  SRR1077288   MT-ND4L_MT-ND4  22732.2       AfAm  Muscle - Skeletal
# 62  SRR1077805   MT-ND4L_MT-ND4  34206.9       AfAm  Muscle - Skeletal
# 63  SRR1080766   MT-ND4L_MT-ND4  47500.9       EuAm  Muscle - Skeletal
# 65  SRR1365448   MT-ND4L_MT-ND4  36600.3       AfAm  Muscle - Skeletal
#
#       short_ID     Sex      Mapping
# 0    GTEX-XPVG    Male  Bicistronic
# 1    GTEX-SSA3    Male  Bicistronic
# 2    GTEX-XYKS  Female  Bicistronic
# 3    GTEX-XUZC  Female  Bicistronic
# 5   GTEX-11WQC    Male  Bicistronic
# 6    GTEX-XPVG    Male  Bicistronic
# 7    GTEX-SSA3    Male  Bicistronic
# 8    GTEX-XYKS  Female  Bicistronic
# 9    GTEX-XUZC  Female  Bicistronic
# 11  GTEX-11WQC    Male  Bicistronic
# 12   GTEX-XPVG    Male  Bicistronic
# 13   GTEX-SSA3    Male  Bicistronic
# 14   GTEX-XYKS  Female  Bicistronic
# 15   GTEX-XUZC  Female  Bicistronic
# 17  GTEX-11WQC    Male  Bicistronic
# 18   GTEX-XPVG    Male  Bicistronic
# 19   GTEX-SSA3    Male  Bicistronic
# 20   GTEX-XYKS  Female  Bicistronic
# 21   GTEX-XUZC  Female  Bicistronic
# 23  GTEX-11WQC    Male  Bicistronic
# 24   GTEX-XPVG    Male  Bicistronic
# 25   GTEX-SSA3    Male  Bicistronic
# 26   GTEX-XYKS  Female  Bicistronic
# 27   GTEX-XUZC  Female  Bicistronic
# 29  GTEX-11WQC    Male  Bicistronic
# 30   GTEX-XPVG    Male  Bicistronic
# 31   GTEX-SSA3    Male  Bicistronic
# 32   GTEX-XYKS  Female  Bicistronic
# 33   GTEX-XUZC  Female  Bicistronic
# 35  GTEX-11WQC    Male  Bicistronic
# 36   GTEX-XPVG    Male  Bicistronic
# 37   GTEX-SSA3    Male  Bicistronic
# 38   GTEX-XYKS  Female  Bicistronic
# 39   GTEX-XUZC  Female  Bicistronic
# 41  GTEX-11WQC    Male  Bicistronic
# 42   GTEX-XPVG    Male  Bicistronic
# 43   GTEX-SSA3    Male  Bicistronic
# 44   GTEX-XYKS  Female  Bicistronic
# 45   GTEX-XUZC  Female  Bicistronic
# 47  GTEX-11WQC    Male  Bicistronic
# 48   GTEX-XPVG    Male  Bicistronic
# 49   GTEX-SSA3    Male  Bicistronic
# 50   GTEX-XYKS  Female  Bicistronic
# 51   GTEX-XUZC  Female  Bicistronic
# 53  GTEX-11WQC    Male  Bicistronic
# 54   GTEX-XPVG    Male  Bicistronic
# 55   GTEX-SSA3    Male  Bicistronic
# 56   GTEX-XYKS  Female  Bicistronic
# 57   GTEX-XUZC  Female  Bicistronic
# 59  GTEX-11WQC    Male  Bicistronic
# 60   GTEX-XPVG    Male  Bicistronic
# 61   GTEX-SSA3    Male  Bicistronic
# 62   GTEX-XYKS  Female  Bicistronic
# 63   GTEX-XUZC  Female  Bicistronic
# 65  GTEX-11WQC    Male  Bicistronic

# %% [markdown]
# def plot_pair_expr(df):
#     sns.set(rc={'figure.figsize':(30,15)},font_scale=2.5)
#     sns.set_style("ticks")
#     ###data = df[df['Tissue']==tissue].sort_values('Gene')
#     # Change labels of Self_rep_race column.
#     data['Groups'] = data['self_rep_race']
#     data['Groups'] = [{'AfAm':'African Americans','EuAm':'European Americans'}[x] for x in data['Groups']]
#     sns.boxplot(data=data, x='Gene', y='TPM', hue='Groups',
#                 hue_order=['European Americans','African Americans'],palette="Blues_r")
#     #sample_size=" (n="+str(data['GTEX_ID'].drop_duplicates().size)+")"
#     s_ea = "EuAm="+str(data[data['self_rep_race']=='EuAm']['short_ID'].drop_duplicates().size)
#     s_aa = "AfAm="+str(data[data['self_rep_race']=='AfAm']['short_ID'].drop_duplicates().size)
#     ##plt.title( "\n" + name +' | '+ tissue + s_ea + s_aa +"\n" , size=30)
#     plt.xticks(rotation=45)
#     plt.xlabel('Genes')
#     plt.ylabel('Normalized gene expression (TPM)')
#     # Legend placement.
#     plt.legend(loc="upper right")
#     # Alternate tissue names.
#     dict_altTiss = {'Esophagus - Muscularis':'Smooth muscle (esophagus)','Muscle - Skeletal':'Muscle (skeletal)','Heart - Left Ventricle':'Heart (ventricle)','Artery - Tibial':'Artery (Tibial)','Whole Blood':'Whole blood','Heart - Atrial Appendage':'Heart (atrium)','Nerve - Tibial':'Nerve (Tibial)'}
#     plt.title( dict_altTiss[tissue] +"( "+ s_ea +" , "+ s_aa +" )\n", size=40, weight="bold" )
#     ## Save figure.
#     ##plt.savefig('../results/boxplot_skeletal_10142021.pdf')
#     plt.show()

# %%
def boxplot_genes(df):
    sns.set(rc={'figure.figsize':(10,7)},font_scale=1.5)
    sns.set_style("ticks")
    sns.boxplot(data=df.sort_values(['Gene']) ,
               x='Gene' ,
               y='value',
               hue='Population',
               hue_order=['AfAm','EuAm'],
               palette="Blues_r"
               )
    plt.ylabel('Normalized gene expression (TPM)')
    plt.xticks(rotation=0)
    
boxplot_genes( df_orig[df_orig['Gene'].isin(['MT-ND4','MT-ND4L','MT-ATP8','MT-ATP6'])] )

# %%
boxplot_genes( df_bic[df_bic['Gene'].isin(['MT-ND4L_MT-ND4','MT-ATP8_MT-ATP6'])] )

# %% [markdown]
# ## Mann Whitney U test.

# %%
### Make table of the 'genes' compared across EuAm vs. AfAm, and 'p-values' of two-sided Mann-Whitney U test.
# Use only when the number of observation in each sample is > 20 and you have 2 independent samples of ranks. 
# Mann-Whitney U is significant if the u-obtained is LESS THAN or equal to the critical value of U.

def mwu_test(df,gene):
    data = df[df['Gene']==gene]
    data_euam = data[data['Population']=='EuAm']
    data_afam = data[data['Population']=='AfAm']
    #return(data_euam)
    results = stats.mannwhitneyu( pd.isnull(data_euam['value']) , pd.isnull(data_afam['value']) , alternative='greater')
    return(results)

#mwu_test(df_orig,'MT-ND4L')
#mwu_test(df_bic,'MT-ND4L_MT-ND4')

# %%
for gene in ['MT-ATP8_MT-ATP6','MT-ND4L_MT-ND4']:
    print(mwu_test(df_bic,gene), gene)
# Out:
# MannwhitneyuResult(statistic=3.0, pvalue=1.0) MT-ATP8_MT-ATP6
# MannwhitneyuResult(statistic=3.0, pvalue=1.0) MT-ND4L_MT-ND4

# %%
for gene in ['MT-ATP8','MT-ATP6','MT-ND4L','MT-ND4']:
    print(mwu_test(df_orig,gene), gene)
# Out:
# MannwhitneyuResult(statistic=3.0, pvalue=1.0) MT-ATP8
# MannwhitneyuResult(statistic=3.0, pvalue=1.0) MT-ATP6
# MannwhitneyuResult(statistic=3.0, pvalue=1.0) MT-ND4L
# MannwhitneyuResult(statistic=3.0, pvalue=1.0) MT-ND4

# %% [markdown]
# ## Two sample t-test.

# %%
# This is a test for the null hypothesis that 2 independent samples have identical average (expected) values. 
# This test assumes that the populations have identical variances by default.
## Apparently no minimum sample size, but power is severely limited.

def ttest_test(df,gene):
    data = df[df['Gene']==gene]
    data_euam = data[data['Population']=='EuAm']
    data_afam = data[data['Population']=='AfAm']
    #return(data_euam)
    results = stats.ttest_ind( data_euam['value'] , data_afam['value'] , alternative='greater')
    return(results)

# %%
for gene in ['MT-ATP8_MT-ATP6','MT-ND4L_MT-ND4']:
    print(ttest_test(df_bic,gene), gene)
# Out:
# Ttest_indResult(statistic=2.460201918422578, pvalue=0.045425620008172546) MT-ATP8_MT-ATP6
# Ttest_indResult(statistic=2.9934487245256998, pvalue=0.028985433185288186) MT-ND4L_MT-ND4

# %%
for gene in ['MT-ATP8','MT-ATP6','MT-ND4L','MT-ND4']:
    print(ttest_test(df_orig,gene), gene)
# Out:
# Ttest_indResult(statistic=1.2170218849177041, pvalue=0.15530092101940762) MT-ATP8
# Ttest_indResult(statistic=2.7171625513126045, pvalue=0.03636163194187859) MT-ATP6
# Ttest_indResult(statistic=4.378253912989867, pvalue=0.011026726642290551) MT-ND4L
# Ttest_indResult(statistic=2.8635265244285497, pvalue=0.03219531425179107) MT-ND4

# %% [markdown]
# ## Correlate bicistronic transcript to single genes.

# %%
df_merged = pd.concat([ df_orig , df_bic ])
df_merged
# Out:
#    Description            Gene    value Population             Tissue  \
# 0   SRR1074719          MT-ND1  34972.3       EuAm  Muscle - Skeletal
# 1   SRR1077288          MT-ND1  16752.3       AfAm  Muscle - Skeletal
# 2   SRR1077805          MT-ND1  19851.8       AfAm  Muscle - Skeletal
# 3   SRR1080766          MT-ND1  32457.1       EuAm  Muscle - Skeletal
# 5   SRR1365448          MT-ND1  20237.1       AfAm  Muscle - Skeletal
# ..         ...             ...      ...        ...                ...
# 60  SRR1074719  MT-ND4L_MT-ND4  63458.3       EuAm  Muscle - Skeletal
# 61  SRR1077288  MT-ND4L_MT-ND4  22732.2       AfAm  Muscle - Skeletal
# 62  SRR1077805  MT-ND4L_MT-ND4  34206.9       AfAm  Muscle - Skeletal
# 63  SRR1080766  MT-ND4L_MT-ND4  47500.9       EuAm  Muscle - Skeletal
# 65  SRR1365448  MT-ND4L_MT-ND4  36600.3       AfAm  Muscle - Skeletal
#
#       short_ID     Sex      Mapping
# 0    GTEX-XPVG    Male     Original
# 1    GTEX-SSA3    Male     Original
# 2    GTEX-XYKS  Female     Original
# 3    GTEX-XUZC  Female     Original
# 5   GTEX-11WQC    Male     Original
# ..         ...     ...          ...
# 60   GTEX-XPVG    Male  Bicistronic
# 61   GTEX-SSA3    Male  Bicistronic
# 62   GTEX-XYKS  Female  Bicistronic
# 63   GTEX-XUZC  Female  Bicistronic
# 65  GTEX-11WQC    Male  Bicistronic
#
# [120 rows x 8 columns]

# %%
df_merged[df_merged['Gene'].isin(['MT-ATP8_MT-ATP6','MT-ND4L_MT-ND4','MT-ATP8','MT-ATP6','MT-ND4L','MT-ND4'])].iloc[:,:-1]
# Out:
#    Description             Gene    value Population             Tissue  \
# 24  SRR1074719          MT-ATP8  37170.2       EuAm  Muscle - Skeletal
# 25  SRR1077288          MT-ATP8  18250.7       AfAm  Muscle - Skeletal
# 26  SRR1077805          MT-ATP8  20734.6       AfAm  Muscle - Skeletal
# 27  SRR1080766          MT-ATP8  21763.8       EuAm  Muscle - Skeletal
# 29  SRR1365448          MT-ATP8  25909.9       AfAm  Muscle - Skeletal
# 30  SRR1074719          MT-ATP6  73196.6       EuAm  Muscle - Skeletal
# 31  SRR1077288          MT-ATP6  29118.7       AfAm  Muscle - Skeletal
# 32  SRR1077805          MT-ATP6  38315.9       AfAm  Muscle - Skeletal
# 33  SRR1080766          MT-ATP6  50287.8       EuAm  Muscle - Skeletal
# 35  SRR1365448          MT-ATP6  39811.5       AfAm  Muscle - Skeletal
# 48  SRR1074719          MT-ND4L  27849.6       EuAm  Muscle - Skeletal
# 49  SRR1077288          MT-ND4L  9841.51       AfAm  Muscle - Skeletal
# 50  SRR1077805          MT-ND4L  14628.5       AfAm  Muscle - Skeletal
# 51  SRR1080766          MT-ND4L  22331.7       EuAm  Muscle - Skeletal
# 53  SRR1365448          MT-ND4L  13869.6       AfAm  Muscle - Skeletal
# 54  SRR1074719           MT-ND4  63503.4       EuAm  Muscle - Skeletal
# 55  SRR1077288           MT-ND4  23770.9       AfAm  Muscle - Skeletal
# 56  SRR1077805           MT-ND4  35573.2       AfAm  Muscle - Skeletal
# 57  SRR1080766           MT-ND4  48194.8       EuAm  Muscle - Skeletal
# 59  SRR1365448           MT-ND4  38404.3       AfAm  Muscle - Skeletal
# 54  SRR1074719  MT-ATP8_MT-ATP6  78093.5       EuAm  Muscle - Skeletal
# 55  SRR1077288  MT-ATP8_MT-ATP6  31216.4       AfAm  Muscle - Skeletal
# 56  SRR1077805  MT-ATP8_MT-ATP6  40442.8       AfAm  Muscle - Skeletal
# 57  SRR1080766  MT-ATP8_MT-ATP6    51532       EuAm  Muscle - Skeletal
# 59  SRR1365448  MT-ATP8_MT-ATP6  42547.7       AfAm  Muscle - Skeletal
# 60  SRR1074719   MT-ND4L_MT-ND4  63458.3       EuAm  Muscle - Skeletal
# 61  SRR1077288   MT-ND4L_MT-ND4  22732.2       AfAm  Muscle - Skeletal
# 62  SRR1077805   MT-ND4L_MT-ND4  34206.9       AfAm  Muscle - Skeletal
# 63  SRR1080766   MT-ND4L_MT-ND4  47500.9       EuAm  Muscle - Skeletal
# 65  SRR1365448   MT-ND4L_MT-ND4  36600.3       AfAm  Muscle - Skeletal
#
#       short_ID     Sex
# 24   GTEX-XPVG    Male
# 25   GTEX-SSA3    Male
# 26   GTEX-XYKS  Female
# 27   GTEX-XUZC  Female
# 29  GTEX-11WQC    Male
# 30   GTEX-XPVG    Male
# 31   GTEX-SSA3    Male
# 32   GTEX-XYKS  Female
# 33   GTEX-XUZC  Female
# 35  GTEX-11WQC    Male
# 48   GTEX-XPVG    Male
# 49   GTEX-SSA3    Male
# 50   GTEX-XYKS  Female
# 51   GTEX-XUZC  Female
# 53  GTEX-11WQC    Male
# 54   GTEX-XPVG    Male
# 55   GTEX-SSA3    Male
# 56   GTEX-XYKS  Female
# 57   GTEX-XUZC  Female
# 59  GTEX-11WQC    Male
# 54   GTEX-XPVG    Male
# 55   GTEX-SSA3    Male
# 56   GTEX-XYKS  Female
# 57   GTEX-XUZC  Female
# 59  GTEX-11WQC    Male
# 60   GTEX-XPVG    Male
# 61   GTEX-SSA3    Male
# 62   GTEX-XYKS  Female
# 63   GTEX-XUZC  Female
# 65  GTEX-11WQC    Male

# %%
def test():
    data = df_merged[df_merged['Gene'].isin(['MT-ATP8_MT-ATP6','MT-ND4L_MT-ND4','MT-ATP8','MT-ATP6','MT-ND4L','MT-ND4'])].iloc[:,:-1]
    data = data[['Description','Gene','value']].pivot(index='Description', columns='Gene')
    #return( data )
    sns.scatterplot( data=data['value'] ,
                    x='MT-ATP8_MT-ATP6' , 
                    y='MT-ATP8' )
    sns.scatterplot( data=data['value'] ,
                    x='MT-ATP8_MT-ATP6' , 
                    y='MT-ATP6' )
    plt.show()
    
    sns.scatterplot( data=data['value'] ,
                    x='MT-ND4L_MT-ND4' , 
                    y='MT-ND4L' )
    sns.scatterplot( data=data['value'] ,
                    x='MT-ND4L_MT-ND4' , 
                    y='MT-ND4' )
    plt.show()
    
test()
